# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
data = pd.read_csv(r"ONINE_FOOD_DELIVERY_ANALYSIS.csv")

# %%
data.head()
# Out:
#     Order_ID Customer_ID  Customer_Age Customer_Gender     City     Area  \
# 0  ORD000001    CUST6948          19.0            Male      NaN  Central
# 1  ORD000002    CUST6515           NaN          Female  Chennai    North
# 2  ORD000003    CUST1765           NaN            Male    Delhi      NaN
# 3  ORD000004    CUST2744           NaN            Male   Mumbai  Central
# 4  ORD000005    CUST4389          57.0          Female  Chennai    South
#
#   Restaurant_ID Restaurant_Name Cuisine_Type  Order_Date  ... Final_Amount  \
# 0        RES936   Restaurant_29      Chinese  10/20/2024  ...          NaN
# 1        RES689  Restaurant_419      Chinese   8/12/2024  ...       4849.0
# 2        RES723  Restaurant_244      Arabian   12/8/2024  ...        737.0
# 3        RES951  Restaurant_178      Chinese   10/8/2024  ...          NaN
# 4        RES419  Restaurant_262      Chinese    2/4/2024  ...        352.0
#
#    Payment_Mode  Order_Status  Cancellation_Reason  Delivery_Partner_ID  \
# ...

# %%
data.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Age', 'Customer_Gender', 'City',
#        'Area', 'Restaurant_ID', 'Restaurant_Name', 'Cuisine_Type',
#        'Order_Date', 'Order_Time', 'Delivery_Time_Min', 'Distance_km',
#        'Order_Value', 'Discount_Applied', 'Final_Amount', 'Payment_Mode',
#        'Order_Status', 'Cancellation_Reason', 'Delivery_Partner_ID',
#        'Delivery_Rating', 'Restaurant_Rating', 'Order_Day', 'Peak_Hour',
#        'Profit_Margin'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Order_ID             100000 non-null  object
#  1   Customer_ID          100000 non-null  object
#  2   Customer_Age         49907 non-null   float64
#  3   Customer_Gender      75144 non-null   object
#  4   City                 83274 non-null   object
#  5   Area                 83315 non-null   object
#  6   Restaurant_ID        100000 non-null  object
#  7   Restaurant_Name      100000 non-null  object
#  8   Cuisine_Type         83115 non-null   object
#  9   Order_Date           98986 non-null   object
#  10  Order_Time           98002 non-null   object
#  11  Delivery_Time_Min    66641 non-null   float64
#  12  Distance_km          66530 non-null   float64
#  13  Order_Value          66673 non-null   float64
# ...

# %%
data.shape
# Out:
# (100000, 25)

# %%
"""
Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Remove the NaN values from the dataset
Cleaning individual columns.
Check for some more Transformations
"""
# Out:
# '\nDeleting redundant columns.\nRenaming the columns.\nDropping duplicates.\nRemove the NaN values from the dataset\nCleaning individual columns.\nCheck for some more Transformations\n'

# %%
data.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Age', 'Customer_Gender', 'City',
#        'Area', 'Restaurant_ID', 'Restaurant_Name', 'Cuisine_Type',
#        'Order_Date', 'Order_Time', 'Delivery_Time_Min', 'Distance_km',
#        'Order_Value', 'Discount_Applied', 'Final_Amount', 'Payment_Mode',
#        'Order_Status', 'Cancellation_Reason', 'Delivery_Partner_ID',
#        'Delivery_Rating', 'Restaurant_Rating', 'Order_Day', 'Peak_Hour',
#        'Profit_Margin'],
#       dtype='object')

# %%
columns_to_keep = ['Order_ID', 'Customer_ID', 'Restaurant_ID', 'Restaurant_Name', 'Cuisine_Type','Order_Date', 'Order_Time','Order_Value', 'Discount_Applied', 'Final_Amount', 'Payment_Mode','Order_Status', 'Cancellation_Reason', 'Delivery_Partner_ID','Delivery_Rating', 'Restaurant_Rating','Order_Day', 'Peak_Hour','Profit_Margin']
columns_to_drop = ['Order_Day','Customer_Age', 'Customer_Gender', 'City', 'Area']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 5

# %%
# 1st way filtering data

# %%
data['Restaurant_Name']
# Out:
# 0         Restaurant_29
# 1        Restaurant_419
# 2        Restaurant_244
# 3        Restaurant_178
# 4        Restaurant_262
#               ...
# 99995    Restaurant_500
# 99996    Restaurant_458
# 99997    Restaurant_273
# 99998    Restaurant_241
# 99999    Restaurant_237
# Name: Restaurant_Name, Length: 100000, dtype: object

# %%
columns_to_keep
# Out:
# ['Order_ID',
#  'Customer_ID',
#  'Restaurant_ID',
#  'Restaurant_Name',
#  'Cuisine_Type',
#  'Order_Date',
#  'Order_Time',
#  'Order_Value',
#  'Discount_Applied',
#  'Final_Amount',
#  'Payment_Mode',
#  'Order_Status',
#  'Cancellation_Reason',
#  'Delivery_Partner_ID',
#  'Delivery_Rating',
#  'Restaurant_Rating',
#  'Order_Day',
#  'Peak_Hour',
#  'Profit_Margin']

# %%
data[columns_to_keep]
# Out:
#         Order_ID Customer_ID Restaurant_ID Restaurant_Name Cuisine_Type  \
# 0      ORD000001    CUST6948        RES936   Restaurant_29      Chinese
# 1      ORD000002    CUST6515        RES689  Restaurant_419      Chinese
# 2      ORD000003    CUST1765        RES723  Restaurant_244      Arabian
# 3      ORD000004    CUST2744        RES951  Restaurant_178      Chinese
# 4      ORD000005    CUST4389        RES419  Restaurant_262      Chinese
# ...          ...         ...           ...             ...          ...
# 99995  ORD099996    CUST3722        RES295  Restaurant_500      Arabian
# 99996  ORD099997    CUST6158        RES157  Restaurant_458      Arabian
# 99997  ORD099998    CUST2155        RES287  Restaurant_273          NaN
# 99998  ORD099999    CUST3015        RES491  Restaurant_241          NaN
# 99999  ORD100000    CUST7959        RES680  Restaurant_237      Chinese
#
#        Order_Date Order_Time  Order_Value  Discount_Applied  Final_Amount  \
# ...

# %%
#2nd way, dropping the columns

# %%
columns_to_drop
# Out:
# ['Order_Day', 'Customer_Age', 'Customer_Gender', 'City', 'Area']

# %%
modify_data = data[columns_to_keep]

# %%
modify_data
# Out:
#         Order_ID Customer_ID Restaurant_ID Restaurant_Name Cuisine_Type  \
# 0      ORD000001    CUST6948        RES936   Restaurant_29      Chinese
# 1      ORD000002    CUST6515        RES689  Restaurant_419      Chinese
# 2      ORD000003    CUST1765        RES723  Restaurant_244      Arabian
# 3      ORD000004    CUST2744        RES951  Restaurant_178      Chinese
# 4      ORD000005    CUST4389        RES419  Restaurant_262      Chinese
# ...          ...         ...           ...             ...          ...
# 99995  ORD099996    CUST3722        RES295  Restaurant_500      Arabian
# 99996  ORD099997    CUST6158        RES157  Restaurant_458      Arabian
# 99997  ORD099998    CUST2155        RES287  Restaurant_273          NaN
# 99998  ORD099999    CUST3015        RES491  Restaurant_241          NaN
# 99999  ORD100000    CUST7959        RES680  Restaurant_237      Chinese
#
#        Order_Date Order_Time  Order_Value  Discount_Applied  Final_Amount  \
# ...

# %%
columns_to_drop
# Out:
# ['Order_Day', 'Customer_Age', 'Customer_Gender', 'City', 'Area']

# %%
data.drop(columns= columns_to_drop, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 data.drop(columns= columns_to_drop, inplace= True)
#
# File c:\Users\jagadhees\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
data.shape
# Out:
# (100000, 22)

# %%
data.isnull().sum()
# Out:
# Order_ID                   0
# Customer_ID                0
# Customer_Gender        24856
# Area                   16685
# Restaurant_Name            0
# Cuisine_Type           16885
# Order_Date              1014
# Order_Time              1998
# Delivery_Time_Min      33359
# Distance_km            33470
# Order_Value            33327
# Discount_Applied       16715
# Final_Amount           55697
# Payment_Mode           19911
# Order_Status               0
# Cancellation_Reason    90969
# Delivery_Partner_ID        0
# Delivery_Rating        16523
# Restaurant_Rating          0
# Order_Day                  0
# Peak_Hour              32962
# Profit_Margin              0
# dtype: int64

# %%
data.dtypes
# Out:
# Order_ID                object
# Customer_ID             object
# Customer_Gender         object
# Area                    object
# Restaurant_Name         object
# Cuisine_Type            object
# Order_Date              object
# Order_Time              object
# Delivery_Time_Min      float64
# Distance_km            float64
# Order_Value            float64
# Discount_Applied       float64
# Final_Amount           float64
# Payment_Mode            object
# Order_Status            object
# Cancellation_Reason     object
# Delivery_Partner_ID     object
# Delivery_Rating        float64
# Restaurant_Rating      float64
# Order_Day               object
# Peak_Hour               object
# Profit_Margin          float64
# dtype: object

# %%
data.describe(include='all')
# Out:
#          Order_ID Customer_ID Customer_Gender   Area Restaurant_Name  \
# count      100000      100000           75144  83315          100000
# unique     100000        8999               3      5             500
# top     ORD099984    CUST2487           Other  South  Restaurant_450
# freq            1          24           25135  16725             246
# mean          NaN         NaN             NaN    NaN             NaN
# std           NaN         NaN             NaN    NaN             NaN
# min           NaN         NaN             NaN    NaN             NaN
# 25%           NaN         NaN             NaN    NaN             NaN
# 50%           NaN         NaN             NaN    NaN             NaN
# 75%           NaN         NaN             NaN    NaN             NaN
# max           NaN         NaN             NaN    NaN             NaN
#
#        Cuisine_Type Order_Date Order_Time  Delivery_Time_Min   Distance_km  \
# ...

# %%
#find out the items sold in the restaurant

# %%
data.nunique()
# Out:
# Order_ID               100000
# Customer_ID              8999
# Customer_Gender             3
# Area                        5
# Restaurant_Name           500
# Cuisine_Type                5
# Order_Date                365
# Order_Time                  1
# Delivery_Time_Min         232
# Distance_km              3402
# Order_Value              4052
# Discount_Applied            5
# Final_Amount             4574
# Payment_Mode                4
# Order_Status                2
# Cancellation_Reason         3
# Delivery_Partner_ID       900
# Delivery_Rating             5
# Restaurant_Rating          26
# Order_Day                   2
# Peak_Hour                   2
# Profit_Margin              71
# dtype: int64

# %%
print(data["Cuisine_Type"].nunique())
# Out:
# 5

# %%
#Give me the list of least 5 selling items

# %%
data.groupby("Cuisine_Type")["Quantity"].sum().sort_values(ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 data.groupby("Cuisine_Type")["Quantity"].sum().sort_values(ascending=False).head()
#
# File c:\Users\jagadhees\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File c:\Users\jagadhees\anaconda3\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# ...

# %%
(data.groupby("Cuisine_Type", as_index=True)["Quantity"].sum().sort_values(ascending=False).head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 (data.groupby("Cuisine_Type", as_index=True)["Quantity"].sum().sort_values(ascending=False).head())
#
# File c:\Users\jagadhees\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File c:\Users\jagadhees\anaconda3\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# ...

# %%
data
# Out:
#         Order_ID Customer_ID Customer_Gender     Area Restaurant_Name  \
# 0      ORD000001    CUST6948            Male  Central   Restaurant_29
# 1      ORD000002    CUST6515          Female    North  Restaurant_419
# 2      ORD000003    CUST1765            Male      NaN  Restaurant_244
# 3      ORD000004    CUST2744            Male  Central  Restaurant_178
# 4      ORD000005    CUST4389          Female    South  Restaurant_262
# ...          ...         ...             ...      ...             ...
# 99995  ORD099996    CUST3722             NaN      NaN  Restaurant_500
# 99996  ORD099997    CUST6158            Male     East  Restaurant_458
# 99997  ORD099998    CUST2155             NaN     East  Restaurant_273
# 99998  ORD099999    CUST3015          Female    North  Restaurant_241
# 99999  ORD100000    CUST7959           Other     East  Restaurant_237
#
#       Cuisine_Type  Order_Date Order_Time  Delivery_Time_Min  Distance_km  \
# ...

# %%
data.dtypes
# Out:
# Order_ID                object
# Customer_ID             object
# Customer_Gender         object
# Area                    object
# Restaurant_Name         object
# Cuisine_Type            object
# Order_Date              object
# Order_Time              object
# Delivery_Time_Min      float64
# Distance_km            float64
# Order_Value            float64
# Discount_Applied       float64
# Final_Amount           float64
# Payment_Mode            object
# Order_Status            object
# Cancellation_Reason     object
# Delivery_Partner_ID     object
# Delivery_Rating        float64
# Restaurant_Rating      float64
# Order_Day               object
# Peak_Hour               object
# Profit_Margin          float64
# dtype: object

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         Order_ID Customer_ID Customer_Gender     Area Restaurant_Name  \
# 0      ORD000001    CUST6948            Male  Central   Restaurant_29
# 1      ORD000002    CUST6515          Female    North  Restaurant_419
# 2      ORD000003    CUST1765            Male      NaN  Restaurant_244
# 3      ORD000004    CUST2744            Male  Central  Restaurant_178
# 4      ORD000005    CUST4389          Female    South  Restaurant_262
# ...          ...         ...             ...      ...             ...
# 99995  ORD099996    CUST3722             NaN      NaN  Restaurant_500
# 99996  ORD099997    CUST6158            Male     East  Restaurant_458
# 99997  ORD099998    CUST2155             NaN     East  Restaurant_273
# 99998  ORD099999    CUST3015          Female    North  Restaurant_241
# 99999  ORD100000    CUST7959           Other     East  Restaurant_237
#
#       Cuisine_Type  Order_Date Order_Time  Delivery_Time_Min  Distance_km  \
# ...

# %%
data
# Out:
#         Order_ID Customer_ID Customer_Gender     Area Restaurant_Name  \
# 0      ORD000001    CUST6948            Male  Central   Restaurant_29
# 1      ORD000002    CUST6515          Female    North  Restaurant_419
# 2      ORD000003    CUST1765            Male      NaN  Restaurant_244
# 3      ORD000004    CUST2744            Male  Central  Restaurant_178
# 4      ORD000005    CUST4389          Female    South  Restaurant_262
# ...          ...         ...             ...      ...             ...
# 99995  ORD099996    CUST3722             NaN      NaN  Restaurant_500
# 99996  ORD099997    CUST6158            Male     East  Restaurant_458
# 99997  ORD099998    CUST2155             NaN     East  Restaurant_273
# 99998  ORD099999    CUST3015          Female    North  Restaurant_241
# 99999  ORD100000    CUST7959           Other     East  Restaurant_237
#
#       Cuisine_Type  Order_Date Order_Time  Delivery_Time_Min  Distance_km  \
# ...

# %%
data["Order_ID"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        ORD000001
# 1        ORD000002
# 2        ORD000003
# 3        ORD000004
# 4        ORD000005
#            ...
# 99995    ORD099996
# 99996    ORD099997
# 99997    ORD099998
# 99998    ORD099999
# 99999    ORD100000
# Name: Order_ID, Length: 100000, dtype: object>

# %%
data["Customer_ID"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        CUST6948
# 1        CUST6515
# 2        CUST1765
# 3        CUST2744
# 4        CUST4389
#            ...
# 99995    CUST3722
# 99996    CUST6158
# 99997    CUST2155
# 99998    CUST3015
# 99999    CUST7959
# Name: Customer_ID, Length: 100000, dtype: object>

# %%
data["Order_Time"].value_counts().sort_index()
# Out:
# Order_Time
# 0:00    98002
# Name: count, dtype: int64

# %%
data["Order_Date"].value_counts().sort_index()
# Out:
# Order_Date
# 1/1/2024     263
# 1/10/2024    298
# 1/11/2024    252
# 1/12/2024    286
# 1/13/2024    266
#             ...
# 9/5/2024     266
# 9/6/2024     268
# 9/7/2024     262
# 9/8/2024     308
# 9/9/2024     274
# Name: count, Length: 365, dtype: int64

# %%
data["Customer_ID"].value_counts()
# Out:
# Customer_ID
# CUST2487    24
# CUST9262    23
# CUST7657    23
# CUST4431    23
# CUST7842    23
#             ..
# CUST8380     1
# CUST8726     1
# CUST2201     1
# CUST5157     1
# CUST4958     1
# Name: count, Length: 8999, dtype: int64

# %%
data["Customer_ID"].value_counts().head(10)
# Out:
# Customer_ID
# CUST2487    24
# CUST9262    23
# CUST7657    23
# CUST4431    23
# CUST7842    23
# CUST1239    22
# CUST8740    22
# CUST7320    22
# CUST5467    22
# CUST9003    22
# Name: count, dtype: int64

# %%
data["Order_Time"].value_counts().sort_index()
# Out:
# Order_Time
# 0:00    98002
# Name: count, dtype: int64

# %%
data.groupby("Cuisine_Type")["Order_ID"].count().sort_values(ascending=False)
# Out:
# Cuisine_Type
# Indian     16685
# Arabian    16658
# Chinese    16651
# Mexican    16602
# Italian    16519
# Name: Order_ID, dtype: int64

# %%
data.sort_values("Order_Value", ascending=False).head(10)
# Out:
#         Order_ID Customer_ID Customer_Gender   Area Restaurant_Name  \
# 39019  ORD039020    CUST7760           Other  North  Restaurant_193
# 95820  ORD095821    CUST3511           Other  North   Restaurant_70
# 31941  ORD031942    CUST9577           Other  South  Restaurant_217
# 94687  ORD094688    CUST8255           Other  South  Restaurant_465
# 38716  ORD038717    CUST9121          Female    NaN  Restaurant_199
# 11350  ORD011351    CUST2892          Female   West  Restaurant_495
# 30281  ORD030282    CUST6975          Female   West   Restaurant_43
# 85416  ORD085417    CUST9310            Male  South  Restaurant_401
# 83028  ORD083029    CUST5128            Male  South  Restaurant_257
# 81395  ORD081396    CUST9010             NaN   West  Restaurant_325
#
#       Cuisine_Type  Order_Date Order_Time  Delivery_Time_Min  Distance_km  \
# 39019      Arabian   8/20/2024       0:00                NaN         3.40
# ...

# %%
data["Order_Date"].value_counts().sort_index()
# Out:
# Order_Date
# 1/1/2024     263
# 1/10/2024    298
# 1/11/2024    252
# 1/12/2024    286
# 1/13/2024    266
#             ...
# 9/5/2024     266
# 9/6/2024     268
# 9/7/2024     262
# 9/8/2024     308
# 9/9/2024     274
# Name: count, Length: 365, dtype: int64

# %%
data.groupby("Restaurant_Name")["Order_ID"].count() \
    .sort_values(ascending=False) \
    .head(10)
# Out:
# Restaurant_Name
# Restaurant_450    246
# Restaurant_309    238
# Restaurant_144    237
# Restaurant_74     236
# Restaurant_435    234
# Restaurant_291    234
# Restaurant_221    234
# Restaurant_338    233
# Restaurant_87     233
# Restaurant_346    232
# Name: Order_ID, dtype: int64

# %%
data.groupby("Restaurant_Name")["Order_Value"].sum() \
    .sort_values(ascending=False) \
    .head(10)
# Out:
# Restaurant_Name
# Restaurant_221    361464.0
# Restaurant_89     349387.0
# Restaurant_382    347794.0
# Restaurant_368    345126.0
# Restaurant_400    343695.0
# Restaurant_467    342908.0
# Restaurant_277    339446.0
# Restaurant_428    339406.0
# Restaurant_312    338353.0
# Restaurant_175    335875.0
# Name: Order_Value, dtype: float64

# %%
data.groupby("Restaurant_Name")["Order_Value"].mean() \
    .sort_values(ascending=False) \
    .head(10)
# Out:
# Restaurant_Name
# Restaurant_489    2430.969466
# Restaurant_179    2411.968000
# Restaurant_464    2379.409836
# Restaurant_165    2369.677966
# Restaurant_361    2369.239316
# Restaurant_495    2368.875912
# Restaurant_330    2366.780303
# Restaurant_174    2360.471831
# Restaurant_391    2360.153226
# Restaurant_91     2359.774194
# Name: Order_Value, dtype: float64

# %%
data.groupby(["Restaurant_Name", "Order_Date"])["Order_ID"].count()
# Out:
# Restaurant_Name  Order_Date
# Restaurant_1     1/1/2024      1
#                  1/14/2024     1
#                  1/16/2024     1
#                  1/17/2024     1
#                  1/18/2024     1
#                               ..
# Restaurant_99    9/14/2024     1
#                  9/18/2024     1
#                  9/20/2024     1
#                  9/30/2024     2
#                  9/5/2024      1
# Name: Order_ID, Length: 76226, dtype: int64

# %%
data.groupby("Restaurant_Name")["Order_ID"].count() \
    .sort_values() \
    .head(10)
# Out:
# Restaurant_Name
# Restaurant_231    153
# Restaurant_398    157
# Restaurant_290    158
# Restaurant_288    163
# Restaurant_311    164
# Restaurant_473    165
# Restaurant_81     166
# Restaurant_109    167
# Restaurant_376    167
# Restaurant_268    167
# Name: Order_ID, dtype: int64

# %%
performance = data.groupby("Restaurant_Name").agg(
    Total_Orders=("Order_ID", "count"),
    Total_Revenue=("Order_Value", "sum"),
    Avg_Order_Value=("Order_Value", "mean")
)

performance.sort_values("Total_Revenue", ascending=False).head(10)
# Out:
#                  Total_Orders  Total_Revenue  Avg_Order_Value
# Restaurant_Name
# Restaurant_221            234       361464.0      2287.746835
# Restaurant_89             219       349387.0      2283.575163
# Restaurant_382            225       347794.0      2273.163399
# Restaurant_368            219       345126.0      2285.602649
# Restaurant_400            220       343695.0      2291.300000
# Restaurant_467            226       342908.0      2029.041420
# Restaurant_277            211       339446.0      2262.973333
# Restaurant_428            222       339406.0      2218.339869
# Restaurant_312            214       338353.0      2197.097403
# Restaurant_175            222       335875.0      2316.379310

# %%
data["Order_Value"].sum()
# Out:
# np.float64(138801860.0)

# %%
data.groupby("Order_Date")["Order_Value"].sum()
# Out:
# Order_Date
# 1/1/2024     378946.0
# 1/10/2024    408697.0
# 1/11/2024    321528.0
# 1/12/2024    441371.0
# 1/13/2024    376587.0
#                ...
# 9/5/2024     370353.0
# 9/6/2024     406458.0
# 9/7/2024     359768.0
# 9/8/2024     452201.0
# 9/9/2024     385913.0
# Name: Order_Value, Length: 365, dtype: float64

# %%
data["Estimated_Profit"] = data["Order_Value"] * 0.20

# %%
data["Estimated_Profit"].sum()
# Out:
# np.float64(27760372.0)

# %%
data.groupby("Restaurant_Name")["Estimated_Profit"].sum() \
    .sort_values(ascending=False)
# Out:
# Restaurant_Name
# Restaurant_221    72292.8
# Restaurant_89     69877.4
# Restaurant_382    69558.8
# Restaurant_368    69025.2
# Restaurant_400    68739.0
#                    ...
# Restaurant_102    40316.0
# Restaurant_473    40154.4
# Restaurant_250    39844.6
# Restaurant_81     39736.6
# Restaurant_290    38594.4
# Name: Estimated_Profit, Length: 500, dtype: float64

# %%
data.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Gender', 'Area', 'Restaurant_Name',
#        'Cuisine_Type', 'Order_Date', 'Order_Time', 'Delivery_Time_Min',
#        'Distance_km', 'Order_Value', 'Discount_Applied', 'Final_Amount',
#        'Payment_Mode', 'Order_Status', 'Cancellation_Reason',
#        'Delivery_Partner_ID', 'Delivery_Rating', 'Restaurant_Rating',
#        'Order_Day', 'Peak_Hour', 'Profit_Margin', 'Estimated_Profit'],
#       dtype='object')

# %%
data["Order_Status"].value_counts()
# Out:
# Order_Status
# Delivered    84964
# Cancelled    15036
# Name: count, dtype: int64

# %%
(data["Order_Status"] == "Cancelled").mean() * 100
# Out:
# np.float64(15.036)

# %%
kpi = {
    "Total_Revenue": data["Order_Value"].sum(),
    "Estimated_Profit": (data["Order_Value"] * 0.20).sum(),
    "Total_Orders": data["Order_ID"].nunique()
}

kpi
# Out:
# {'Total_Revenue': np.float64(138801860.0),
#  'Estimated_Profit': np.float64(27760372.0),
#  'Total_Orders': 100000}
